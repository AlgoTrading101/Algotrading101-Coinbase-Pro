# %%
import cbpro
c = cbpro.PublicClient()

# %%
book = c.get_product_order_book('BTC-USD', level=2)
book
# Out:
# {'bids': [['36215.46', '0.5067', 4],
#   ['36213.43', '0.00760913', 1],
#   ['36213.09', '0.01173576', 1],
#   ['36211.64', '0.10116586', 1],
#   ['36208.79', '0.08', 1],
#   ['36205.3', '0.005', 1],
#   ['36205.29', '0.04945257', 1],
#   ['36202.66', '0.171', 1],
#   ['36201.96', '0.05', 1],
#   ['36201.3', '0.1', 1],
#   ['36199.51', '0.13809548', 1],
#   ['36198.87', '0.5976', 1],
#   ['36196.54', '0.45345869', 1],
#   ['36196.53', '0.24538223', 1],
#   ['36195.42', '0.03', 1],
#   ['36193.48', '0.13810064', 1],
#   ['36193.24', '0.41725635', 1],
#   ['36192.84', '0.01998493', 1],
#   ['36192.74', '0.01', 1],
#   ['36189.46', '0.22338544', 1],
#   ['36189.45', '0.0005', 1],
#   ['36187.58', '0.17', 1],
#   ['36185.64', '0.876', 1],
#   ['36185.55', '0.66639148', 3],
#   ['36185.54', '0.00546286', 1],
#   ['36185.03', '0.13813029', 1],
#   ['36184.24', '0.65', 1],
#   ['36180.45', '0.10241467', 1],
#   ['36180', '0.0001', 1],
#   ['36179.07', '0.21575451', 1],
# ...
